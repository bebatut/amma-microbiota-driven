# %% [markdown]
# CML effect: comparison with PBS data
#
# **Need to run first:**
# - [`../0-prepare_data`](../0-prepare_data.ipynb)
# - [`1-extract_samples`](1-extract_samples.ipynb)
# - [`2-run_dge_analysis`](2-run_dge_analysis.ipynb)
# - [`3-previsualize_data`](3-previsualize_data.ipynb)
# - [`4-analyze_microbiota_effect_given_ages`](4-analyze_microbiota_effect_given_ages.ipynb)
#
# **Table of content**
# 1. [Prepare data](#Prepare-data)
# 2. [Differential expression analysis](#Differential-expression-analysis)
# 3. [Z-scores of CML vs PBS DEGs in non CML / PBS samples](#Z-scores-of-CML-vs-PBS-DEGs-in-non-CML-/-PBS-samples)
# 4. [Volcano plots for SPF vs GF highlighting DEG in CML vs PBS](#Volcano-plots-for-SPF-vs-GF-highlighting-DEG-in-CML-vs-PBS)
#
# *Generated from a Jupyter Notebook - [Sources](https://github.com/bebatut/neuromac_GF_mices/blob/master/src/full/6-analyze_cml_effect.ipynb)*

# %% [markdown]
# # Load

# %%
source("../load_libraries.R")
# Out:
# Warning message:
# “package ‘matrixStats’ was built under R version 3.6.3”
# Warning message:
# “package ‘pheatmap’ was built under R version 3.6.3”
# Warning message:
# “package ‘gplots’ was built under R version 3.6.3”
# Warning message:
# “package ‘UpSetR’ was built under R version 3.6.3”
# Warning message:
# “package ‘ggplot2’ was built under R version 3.6.3”
# Warning message:
# “package ‘plyr’ was built under R version 3.6.3”
# Warning message:
# “package ‘RColorBrewer’ was built under R version 3.6.3”
# Warning message:
# “package ‘viridis’ was built under R version 3.6.3”
# Warning message:
# “package ‘viridisLite’ was built under R version 3.6.3”
# Warning message:
# “package ‘rentrez’ was built under R version 3.6.3”
# Warning message:
# “package ‘BiasedUrn’ was built under R version 3.6.3”
# Warning message:
# “package ‘dendextend’ was built under R version 3.6.3”
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.3”
# Warning message:
# “package ‘XML’ was built under R version 3.6.3”
# Warning message:
# “package ‘dynamicTreeCut’ was built under R version 3.6.3”
# Warning message:
# “package ‘fastcluster’ was built under R version 3.6.3”
# Allowing multi-threading with up to 8 threads.
# Warning message:
# “package ‘igraph’ was built under R version 3.6.3”
# Warning message:
# “package ‘threejs’ was built under R version 3.6.3”
# Warning message:
# “package ‘htmlwidgets’ was built under R version 3.6.3”
# Warning message:
# “package ‘xlsx’ was built under R version 3.6.3”
# Warning message:
# “package ‘reshape’ was built under R version 3.6.3”
# Warning message:
# “package ‘plotly’ was built under R version 3.6.3”
# Warning message:
# “package ‘ggfortify’ was built under R version 3.6.3”
# Warning message:
# “package ‘gridExtra’ was built under R version 3.6.3”
# Warning message:
# “package ‘sinaplot’ was built under R version 3.6.3”
# Warning message:
# “package ‘dplyr’ was built under R version 3.6.3”
# Warning message:
# “package ‘tibble’ was built under R version 3.6.3”
# Warning message:
# “package ‘factoextra’ was built under R version 3.6.3”
# Warning message:
# “package ‘tidyr’ was built under R version 3.6.3”
# Warning message:
# “package ‘ggrepel’ was built under R version 3.6.3”
# preparing gene to GO mapping data...
#
# preparing IC data...
#
# preparing gene to GO mapping data...
#
# preparing IC data...
#
# preparing gene to GO mapping data...
#
# preparing IC data...

# %%
source("../functions.R")

# %% [markdown]
# Load the gene length

# %%
gene_length = read.csv("../../data/gene_length.tabular", sep="\t", h = F) %>%
    rename('length' = 'V2') %>%
    rename('gene' = 'V1')

# %% [markdown]
# Load the count table

# %%
counts = read.csv("../../data/cml_pbs_counts.tabular", sep="\t") %>%
    rename('gene' = 'X.KEY')

# %%
dp = "../../results/dge/microbiota-driven/"
dir_path = paste(dp, "6-analyze_cml_effect/", sep='')
dir.create(dir_path, showWarnings = FALSE)

# %% [markdown]
# # Prepare data

# %% [markdown]
# Rename columns due to confusion in labelling of FastQ files

# %%
counts = counts %>%
    rename('CML-1' = 'PBS_3') %>%
    rename('CML-2' = 'PBS_4') %>%
    rename('CML-3' = 'CML_2') %>%
    rename('CML-4' = 'PBS_1') %>%
    rename('PBS-1' = 'PBS_2') %>%
    rename('PBS-2' = 'CML_4') %>%
    rename('PBS-3' = 'CML_3') %>%
    rename('PBS-4' = 'CML_1') %>%
    select(c('gene', 'CML-1', 'CML-2', 'CML-3', 'CML-4', 'PBS-1', 'PBS-2', 'PBS-3', 'PBS-4'))

# %%
counts
# Out:
#       gene          CML-1 CML-2 CML-3 CML-4 PBS-1 PBS-2 PBS-3 PBS-4
# 1     0610005C13Rik    4     3     2     3     2     2    12     9
# 2     0610007P14Rik  843   599   726   711   529   524   703   676
# 3     0610009B22Rik 1252   786   966   894   946  1014  1254  1066
# 4     0610009L18Rik   58    49    70    67    42    62    23    40
# 5     0610009O20Rik  228   306   375   257   271   371   428   377
# 6     0610010B08Rik    0     0     0     0     0     0     0     0
# 7     0610010F05Rik  367   566   453   477   551   432   798   562
# 8     0610010K14Rik 1382  1382  1185  1369  1356  1507  1362  1459
# 9     0610011F06Rik  188   130   215   148   153    98   168   152
# 10    0610012G03Rik  586   636   651   641   608   666   871   768
# 11    0610030E20Rik 1164  1165  1201  1180  1191  1128  1268  1133
# 12    0610031O16Rik    0     0     0     0     0     0     0     0
# 13    0610037L13Rik  564   579   586   705   390   598   568   544
# 14    0610038B21Rik    0     3     6     0     0     4     1     1
# 15    0610039H22Rik    2     3     0     0     1     0     0     1
# 16    0610039K10Rik   51    38    33    31    22    21    46    31
# 17    0610040B10Rik   40    13    19    10     7     5     6     9
# 18    0610040F04Rik    0     0     0     0     0     0     0     0
# 19    0610040J01Rik 5352  5708  5966  5346  5582  5571  8139  6793
# 20    0610043K17Rik    0     6     5     1     5     6     0     3
# 21    1010001N08Rik    0     0     0     0     0     0     0     0
# 22    1110001J03Rik   90   103   115   103   139   120   138   145
# 23    1110002L01Rik   60    77    69    55    75    73    86    79
# 24    1110004E09Rik  241   182   168   177   227   110   213   227
# 25    1110004F10Rik 2185  1857  1781  1893  1725  1889  2212  2033
# 26    1110006O24Rik   35    45    32    37    20    25    39    38
# 27    1110007C09Rik  657   709   718   581   653   653   752   781
# 28    1110008F13Rik  922   907   958   932   884   863  1157  1116
# 29    1110008L16Rik  299   408   289   276   342   316   371   340
# 30    1110008P14Rik   46    23    59    23    94    26    75    66
# ⋮     ⋮             ⋮     ⋮     ⋮     ⋮     ⋮     ⋮     ⋮     ⋮
# 24392 Zscan26        519   433   473   368   440   457   551   478
# 24393 Zscan29       1147  1203   932   930  1134   891  2298  1469
# 24394 Zscan4a          0     0     0     0     0     0     0     0
# 24395 Zscan4b          0     0     0     0     0     0     0     0
# 24396 Zscan4c          0     0     0     0     0     0     0     0
# 24397 Zscan4d          0     0     0     0     0     0     0     0
# 24398 Zscan4f          0     0     0     0     0     0     0     0
# 24399 Zscan5b          0     0     0     0     0     0     0     0
# 24400 Zswim1         409   505   706   539   612   477   781   578
# 24401 Zswim2           0     0     0     0     0     0     0     0
# 24402 Zswim3         362   441   350   351   239   360   401   344
# 24403 Zswim4         386   527   448   345   413   496   670   603
# 24404 Zswim5         176   102   265   263   372   329   361   310
# 24405 Zswim6        1102  1051  1186   983   810  1296  1677  1154
# 24406 Zswim7         192   122    77    60    65    51    90    84
# 24407 Zswim8         259   360   325   308   319   215   429   320
# 24408 Zufsp         1227  1429  1037  1008   912  1295  1219  1156
# 24409 Zw10           467   651   423   538   453   578  1127   780
# 24410 Zwilch          41     0    37     0     0    11    15     8
# 24411 Zwint         1522  1585  1366  1290  1414  1383  2122  1735
# 24412 Zxda           257   234   321   387   292   361   463   315
# 24413 Zxdb           301   322   265   304   285   125   415   296
# 24414 Zxdc           804   960  1083   912   600  1090  1466  1084
# 24415 Zyg11a           0     0     0     0     0     0     0     0
# 24416 Zyg11b        2472  2702  2077  1349  2148  2633  3073  2497
# 24417 Zyx           2027  2577  2115  2404  2546  2570  2774  2706
# 24418 Zzef1          514   549   594   448   645   776   828   648
# 24419 Zzz3           922   868   850   762   572  1140  1294   931
# 24420 a                0     2     0     1     0     0     0     1
# 24421 l7Rn6          664   558   591   536   731   632   626   705

# %% [markdown]
# ## Check data

# %%
head(counts)
# Out:
#   gene          CML-1 CML-2 CML-3 CML-4 PBS-1 PBS-2 PBS-3 PBS-4
# 1 0610005C13Rik    4    3     2     3     2      2    12     9
# 2 0610007P14Rik  843  599   726   711   529    524   703   676
# 3 0610009B22Rik 1252  786   966   894   946   1014  1254  1066
# 4 0610009L18Rik   58   49    70    67    42     62    23    40
# 5 0610009O20Rik  228  306   375   257   271    371   428   377
# 6 0610010B08Rik    0    0     0     0     0      0     0     0

# %% [markdown]
# Percentage of gene names in count file that are in gene length file

# %%
100 * sum(counts$gene %in% gene_length$gene)/length(counts$gene)
# Out:
# [1] 100

# %% [markdown]
# Percentage of gene names in ene length file that are in count file

# %%
100 * sum(gene_length$gene %in% counts$gene)/length(gene_length$gene)
# Out:
# [1] 100

# %% [markdown]
# ## Remove spurious data

# %% [markdown]
# Remove the rows with only zeros (printed: before / after)

# %%
dim(counts)
# Out:
# [1] 24421     9

# %%
counts = counts %>%
    mutate(sumVar = rowSums(.[2:9])) %>%
    filter(sumVar > 1) %>%
    select(-sumVar)

# %%
dim(counts)
# Out:
# [1] 15305     9

# %% [markdown]
# ## Check and clean genes names

# %% [markdown]
# Rename the genes to be sure there is a map with Entrez Gene Identifers:

# %%
cml_counts = counts

# %%
# Extract mapping new names
load("../../results/dge/prepared_counts.RData")
prepared_counts = counts %>%
    rownames_to_column('gene')
original_counts = read.csv("../../data/counts.tabular", sep="\t") %>%
    rename('gene' = 'Gene') %>%
    select(names(prepared_counts)) %>%
    mutate(sumVar = rowSums(.[2:62])) %>%
    filter(sumVar > 1) %>%
    select(-sumVar)
in_orig_not_in_prep_counts = dplyr::setdiff(original_counts, prepared_counts)
in_prep_not_in_orig_counts = dplyr::setdiff(prepared_counts, original_counts)
if(identical(in_orig_not_in_prep_counts$"GF_104w_F_1_2", in_prep_not_in_orig_counts$"GF_104w_F_1_2")){
    new_names = dplyr::tibble(gene = in_orig_not_in_prep_counts$gene, new = in_prep_not_in_orig_counts$gene)}
head(new_names)
# Out:
#   gene          new
# 1 0610007P14Rik Erg28
# 2 0610009O20Rik Dele1
# 3 0610011F06Rik Mettl26
# 4 0610037L13Rik Czib
# 5 1110001J03Rik Fmc1
# 6 1110004E09Rik Cfap298

# %%
rename_genes = function(table, mapping, col_to_check){
    tmp_table = dplyr::full_join(table, mapping, by = "gene") %>%
        filter(!is.na(.[,col_to_check]))
    correct_name_table = tmp_table %>%
        filter(is.na(new)) %>%
        select(-new)
    to_correct_name_table = tmp_table %>%
        filter(!is.na(new)) %>%
        select(-gene) %>%
        rename(gene = new)
    return(dplyr::union(correct_name_table, to_correct_name_table))
}

# %%
# Apply the mapping to rename genes on count table
counts = rename_genes(cml_counts, new_names, 2)
dim(counts)
# Out:
# [1] 15305     9

# %%
# Apply the mapping to rename genes on gene length table
# and filter to keep the same names as in count table
gene_length = rename_genes(gene_length, new_names, 2) %>%
    filter(gene %in% counts$gene)
dim(gene_length)
# Out:
# [1] 15306     2

# %% [markdown]
# ## Create metadata

# %% [markdown]
# Extract the description of the samples

# %%
samples_names = names(counts %>% select(-gene))
metadata = as_tibble(t(sapply(sapply(samples_names, strsplit, split = "-"), unlist))) %>%
    mutate(sample = samples_names) %>%
    rename(treatment = V1) %>%
    rename(replicate = V2) 
metadata
# Out:
# Warning message:
# “The `x` argument of `as_tibble.matrix()` must have unique column names if `.name_repair` is omitted as of tibble 2.0.0.
# Using compatibility `.name_repair`.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
#   treatment replicate sample
# 1 CML       1         CML-1
# 2 CML       2         CML-2
# 3 CML       3         CML-3
# 4 CML       4         CML-4
# 5 PBS       1         PBS-1
# 6 PBS       2         PBS-2
# 7 PBS       3         PBS-3
# 8 PBS       4         PBS-4

# %% [markdown]
# # Differential expression analysis

# %%
count_mat = as.matrix(counts %>% select(-gene))
rownames(count_mat) = counts$gene
head(count_mat)
# Out:
#               CML-1 CML-2 CML-3 CML-4 PBS-1 PBS-2 PBS-3 PBS-4
# 0610005C13Rik    4     3     2     3     2     2    12     9
# 0610009B22Rik 1252   786   966   894   946  1014  1254  1066
# 0610009L18Rik   58    49    70    67    42    62    23    40
# 0610010F05Rik  367   566   453   477   551   432   798   562
# 0610010K14Rik 1382  1382  1185  1369  1356  1507  1362  1459
# 0610012G03Rik  586   636   651   641   608   666   871   768

# %% [markdown]
# Construct DESeqDataSet

# %%
dds = DESeqDataSetFromMatrix(
        countData = count_mat,
        colData = metadata,
        design = ~ treatment)
# Out:
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”

# %%
# organize levels of the factor (PBS being the reference)
dds$treatment = relevel(dds$treatment, ref="PBS")

# %% [markdown]
# ## Testing how the complexification of the model explain the data

# %% [markdown]
# % genes with significant LRT adjusted p-value for the model with treatment as factor compared to a model without any factors

# %%
dge = DESeq(dds, test="LRT", reduced = ~ 1)
LRT_res = results(dge, alpha=0.05)
nb = get_sign_padj(LRT_res)
100*nb/dim(LRT_res)[1]
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
# [1] 0.2221496

# %% [markdown]
# ## Exploratory analysis and visualization

# %% [markdown]
# We use here the variance stabilizing transformation

# %%
vsd = vst(dds, blind = FALSE)

# %% [markdown]
# Distances between the samples

# %%
sampleDists = dist(t(assay(vsd)))
sampleDistMatrix = as.matrix( sampleDists )
colnames(sampleDistMatrix) = NULL
colors = colorRampPalette( rev(brewer.pal(9, "Blues")) )(255)
pheatmap(sampleDistMatrix,
         clustering_distance_rows = sampleDists,
         clustering_distance_cols = sampleDists,
         col = colors,
         fontsize = 6)
# Out:
# plot without title

# %% [markdown]
# PCA plot

# %%
pcaData = plotPCA(vsd, intgroup = c("treatment"), returnData = TRUE)
percentVar = round(100 * attr(pcaData, "percentVar"))
ggplot(pcaData, aes(x = PC1, y = PC2, color = treatment)) +
  geom_point(size =3) +
  xlab(paste0("PC1: ", percentVar[1], "% variance")) +
  ylab(paste0("PC2: ", percentVar[2], "% variance")) +
  coord_fixed()
# Out:
# plot without title

# %% [markdown]
# ## Differential expression analysis

# %%
dge = DESeq(dds)
# Out:
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %% [markdown]
# Extract the normalized counts

# %%
norm_counts = counts(dge, normalized = TRUE)

# %% [markdown]
# ## Extraction of the differentially expressed genes

# %%
sign_adj_pvalue = 0.05

# %% [markdown]
# Extract results

# %%
res = results(dge, alpha=0.05, test="Wald")
deg_results = as.data.frame(res) %>%
        rownames_to_column('gene')

# %%
norm_counts = as.data.frame(norm_counts) %>%
    rownames_to_column('gene')

# %% [markdown]
# ### DEG with abs(FC) > 1.5

# %%
sign_fc = 1.5
deg1 = deg_results %>%
    filter(padj < sign_adj_pvalue & abs(log2FoldChange) >= log2(sign_fc))

# %% [markdown]
# Genes with significant p-values and abs(FC) >= 1.5

# %%
deg1$gene
# Out:
#  [1] "2810013P06Rik" "4833419F23Rik" "A430033K04Rik" "AI854703"
#  [5] "Atad2"         "C4b"           "Ccl22"         "Cenpe"
#  [9] "Cers4"         "Chic1"         "Chil3"         "F630028O10Rik"
# [13] "Fos"           "Gbp6"          "Glb1l"         "Gm5420"
# [17] "Hsph1"         "Igf2bp2"       "Ipo4"          "Itpr3"
# [21] "Kcna7"         "Ltf"           "Maob"          "N4bp3"
# [25] "Nek5"          "Ngp"           "Pglyrp1"       "Rora"
# [29] "S100a8"        "S100a9"        "Scai"          "Sema3c"
# [33] "Setx"          "Sh2d5"         "She"           "Snap91"
# [37] "Snhg17"        "Tle6"          "Ttc37"         "Vat1l"
# [41] "Wdr5b"         "Zfp414"        "Zkscan2"

# %%
length(deg1$gene)
# Out:
# [1] 43

# %%
deg1 = deg1 %>%
    left_join(norm_counts, by='gene') %>%
    select(-c(baseMean, lfcSE, stat, pvalue))

# %%
deg1 %>% write.table(file = paste(dir_path, 'high_fc_deg.csv'), sep="\t", quote=F, row.names=F)

# %%
deg1 %>%
    left_join(norm_counts, by='gene')
# Out:
#    gene          log2FoldChange padj         CML-1.x     CML-2.x
# 1  2810013P06Rik  0.7895124     3.850820e-02 1017.184367  559.331505
# 2  4833419F23Rik  4.1105648     1.905493e-02   11.336401   50.196417
# 3  A430033K04Rik  0.6319824     2.728155e-02  556.514243  547.038505
# 4  AI854703      -6.2457068     7.882744e-03    1.030582    0.000000
# 5  Atad2         -0.9471494     4.650228e-02  207.146968  174.150835
# 6  C4b           -2.1075094     7.054642e-07   94.813538  150.589251
# 7  Ccl22         -3.3443469     3.883425e-02    8.244655   22.537167
# 8  Cenpe         -5.9649109     1.105035e-02    0.000000    0.000000
# 9  Cers4          1.6496472     9.171215e-03   91.721792  134.198584
# 10 Chic1          5.0092233     7.494311e-03   71.110153   13.317417
# 11 Chil3          9.7334149     1.582286e-02  116.455758  413.864337
# 12 F630028O10Rik  6.1687966     4.731114e-02    3.091746   10.244167
# 13 Fos            0.9804601     3.914332e-02  450.364304  333.959836
# 14 Gbp6          -5.9728458     1.582286e-02    0.000000    1.024417
# 15 Glb1l         -1.2517687     4.136833e-02  127.792160   74.782417
# 16 Gm5420         2.7892599     9.194486e-03   64.926662   33.805750
# 17 Hsph1         -1.0536145     2.432693e-03  570.942390  914.804091
# 18 Igf2bp2        0.9943598     4.622859e-02  419.446846  346.252836
# 19 Ipo4          -0.6588971     1.036467e-02  494.679327  594.161672
# 20 Itpr3         -1.4114863     4.738703e-03  111.302849   67.611501
# 21 Kcna7         -4.9706309     3.647687e-02    2.061164    1.024417
# 22 Ltf           10.7709230     4.617099e-02  257.645483  589.039588
# 23 Maob          -6.8860799     9.934078e-04    0.000000    0.000000
# 24 N4bp3         -4.0208410     2.703548e-02    2.061164    4.097667
# 25 Nek5          -3.9313311     8.700338e-03    7.214074    0.000000
# 26 Ngp            9.9691827     3.186159e-03  443.150231 1318.424261
# 27 Pglyrp1        6.9037462     2.719739e-02   11.336401   34.830167
# 28 Rora           0.7249272     3.573616e-02  304.021670  305.276169
# 29 S100a8        12.0335434     2.679847e-02  504.985147 1207.787260
# 30 S100a9        11.5005318     3.647687e-02  279.287704  800.069423
# 31 Scai           0.7108604     4.985879e-02  250.431409  218.200752
# 32 Sema3c        -7.0818253     4.859349e-04    0.000000    0.000000
# 33 Setx          -0.6912896     4.617099e-02  440.058485  593.137255
# 34 Sh2d5         -4.5304961     4.875265e-02    0.000000    0.000000
# 35 She            7.0867462     2.432693e-03   37.100950    3.073250
# 36 Snap91        -6.4069605     2.432693e-03    1.030582    0.000000
# 37 Snhg17         2.0160120     1.299474e-03   74.201899   61.465001
# 38 Tle6          -5.8655828     4.875265e-02    0.000000    0.000000
# 39 Ttc37         -0.7637835     2.432693e-03  410.171609  495.817671
# 40    1.030582    1.024417    0.000000   1.107803   69.095804   34.681842
# 41  385.437643  374.936503  334.036494 354.496934  288.259056  194.830350
# 42  185.504748  160.833418  209.570667 210.482555  129.554632   82.624389
# 43   30.917458   60.440584   25.531452  23.263861    0.000000    6.120325
#    PBS-3.y     PBS-4.y
# 1   548.252218  470.7612415
# 2     3.088745    0.8983993
# 3   393.814974  341.3917400
# 4     3.860931   20.6631843
# 5   529.719749  412.3652860
# 6   738.982215  416.8572826
# 7    40.153684   66.4815494
# 8    11.582793   17.9679863
# 9    28.570890   34.1391740
# 10    4.633117    0.8983993
# 11    0.000000    0.0000000
# 12    0.000000    0.0000000
# 13  315.051979  228.1934262
# 14   22.393400   10.7807918
# 15  226.250563  238.9742180
# 16    3.088745   11.6791911
# 17 2104.979643 1467.0860829
# 18  150.576313  155.4230817
# 19  944.383750  892.1105207
# 20  236.288984  189.5622557
# 21    3.860931   15.2727884
# 22    0.000000    0.0000000
# 23   14.671538   23.3583822
# 24   29.343076   34.1391740
# 25   24.709959   35.9359726
# 26    0.000000    0.8983993
# 27    0.000000    0.0000000
# 28  238.605543  211.1238392
# 29    0.000000    0.0000000
# 30    0.000000    0.0000000
# 31  159.070362  123.9791056
# 32   20.849028   18.8663856
# 33  934.345330  736.6874390
# 34   45.558987   16.1711877
# 35    0.000000    0.0000000
# 36    7.721862   30.5455767
# 37   13.899352   19.7647849
# 38    9.266235   11.6791911
# 39  730.488167  628.8795211
# 40   19.304656   29.6471774
# 41  220.073073  191.3590543
# 42   82.623926   98.8239247
# 43    1.544372    7.1871945

# %% [markdown]
# ### DEG with abs(FC) > 0.58

# %%
sign_fc = 0.58
deg2 = deg_results %>%
    filter(padj < sign_adj_pvalue & abs(log2FoldChange) >= log2(sign_fc))

# %% [markdown]
# Genes with significant p-values and abs(FC) >= 0.58

# %%
deg2$gene
# Out:
#  [1] "2810013P06Rik" "4833419F23Rik" "A430033K04Rik" "AI854703"
#  [5] "Alkbh4"        "Atad2"         "Atp7a"         "C4b"
#  [9] "Ccl22"         "Cenpe"         "Cers4"         "Chic1"
# [13] "Chil3"         "Clk1"          "Dcun1d4"       "F630028O10Rik"
# [17] "Fos"           "Gbp6"          "Glb1l"         "Gm5420"
# [21] "Hsph1"         "Igf2bp2"       "Ipo4"          "Itpr3"
# [25] "Kcna7"         "Ltf"           "Maob"          "N4bp3"
# [29] "Nek5"          "Ngp"           "Npnt"          "Pacs2"
# [33] "Pglyrp1"       "Rora"          "S100a8"        "S100a9"
# [37] "Scai"          "Sema3c"        "Setx"          "Sh2d5"
# [41] "She"           "Slc39a8"       "Snap91"        "Snhg17"
# [45] "Tbc1d23"       "Tle6"          "Ttc37"         "Unk"
# [49] "Usp7"          "Vat1l"         "Wdr5b"         "Xpo1"
# [53] "Xpo7"          "Zfp414"        "Zkscan2"

# %%
length(deg2$gene)
# Out:
# [1] 55

# %% [markdown]
# ## Comparison with DEG extracted by Omar

# %%
cml_pbs_deg = read.csv("../../data/cml_pbs_deg.tabular", sep="\t")
cml_pbs_deg$Gene
# Out:
#  [1] "S100a8"        "Ngp"           "Ltf"           "Camp"
#  [5] "Chil3"         "Lcn2"          "S100a9"        "C4b"
#  [9] "Farp1"         "Cd177"         "Vsig10"        "Cers4"
# [13] "Ttc37"         "Hspa1b"        "Rabl3"         "Itpr3"
# [17] "Foxn2"         "Zfp414"        "Gm26917"       "4933417C20Rik"
# [21] "Gm37298"       "Hsph1"         "Gm37352"       "Uprt"
# [25] "4930518I15Rik" "Gm43984"

# %% [markdown]
# DEG from Omar's data

# %%
cml_pbs_deg$Gene
# Out:
#  [1] "S100a8"        "Ngp"           "Ltf"           "Camp"
#  [5] "Chil3"         "Lcn2"          "S100a9"        "C4b"
#  [9] "Farp1"         "Cd177"         "Vsig10"        "Cers4"
# [13] "Ttc37"         "Hspa1b"        "Rabl3"         "Itpr3"
# [17] "Foxn2"         "Zfp414"        "Gm26917"       "4933417C20Rik"
# [21] "Gm37298"       "Hsph1"         "Gm37352"       "Uprt"
# [25] "4930518I15Rik" "Gm43984"

# %%
length(cml_pbs_deg$Gene)
# Out:
# [1] 26

# %% [markdown]
# Number of DEG with significant p-values and abs(FC) > 1.5 that are in DEG extracted by Omar

# %%
sum(deg1$gene %in% cml_pbs_deg$Gene)
# Out:
# [1] 11

# %% [markdown]
# Number of DEG with significant p-values and abs(FC) > 0.58 that are in DEG extracted by Omar

# %%
sum(deg2$gene %in% cml_pbs_deg$Gene)
# Out:
# [1] 11

# %% [markdown]
# Investigation of Omar's data

# %%
omar = cml_pbs_deg %>%
    arrange(Gene) %>%
    rename(gene = Gene) %>%
    select(-c(Base.mean, StdErr, Wald.Stats, P.value))
my = deg_results %>%
    left_join(norm_counts, by='gene') %>%
    select(-c(baseMean, lfcSE, stat, pvalue))
joint_data = dplyr::left_join(omar, my, by = "gene") %>%
    mutate('deg' = (padj < sign_adj_pvalue & abs(log2FoldChange) >= log2(sign_fc)))

# %%
joint_data
# Out:
#    gene          log2.FC.   P.adj        PBS_1       PBS_2        PBS_3
# 1  4930518I15Rik  0.5813053 5.196073e-03    41.40551    66.635105    71.80520
# 2  4933417C20Rik  0.5930864 2.684696e-03    17.43390    19.477954    14.82934
# 3  C4b           -0.9462081 1.110000e-08   327.97521   345.477393   736.78381
# 4  Camp           1.5316696 9.590000e-28     0.00000     0.000000     0.00000
# 5  Cd177          0.6177664 7.040000e-06     0.00000     0.000000     0.00000
# 6  Cers4          0.7468119 6.390000e-05    39.22627    46.131996    28.87818
# 7  Chil3          1.2554221 1.500000e-19     0.00000     1.025155     0.00000
# 8  Farp1         -0.8042760 5.820000e-06   141.65042   101.490391   139.70795
# 9  Foxn2         -0.6160310 1.008326e-03   452.19174   419.288587   668.10057
# 10 Gm26917       -0.5937446 1.687751e-03 13130.99430 19428.746440 23192.29959
# 11 Gm37298        0.6153384 3.059895e-03    45.76398    80.987282    85.07355
# 12 Gm37352        0.5962007 3.083542e-03    66.46674    57.408706    54.63439
# 13 Gm43984        0.5822144 5.591232e-03    54.48093    63.559639   120.97615
# 24 6.408581e+01   25.50564    18.58599    35.00363 ⋯ 7.019492e-01  12.36698
# 25 2.746535e+01  145.89224   163.14368   106.07160 ⋯ 2.444439e-01 147.37322
# 26 8.239604e+01  164.25630   144.55770   193.05031 ⋯ 3.697553e-02 185.50475
#    CML-2      CML-3      CML-4     PBS-1      PBS-2       PBS-3
# 1          NA         NA        NA         NA          NA         NA
# 2          NA         NA        NA         NA          NA         NA
# 3   150.58925  121.27440  58.71355  328.20507  348.858532  738.98222
# 4   438.45034  364.88700   0.00000    0.00000    0.000000    0.00000
# 5    48.14758  131.91250   0.00000    0.00000    0.000000    0.00000
# 6   134.19858   93.61532  85.30082   19.43319   46.922493   28.57089
# 7   413.86434  435.09849   0.00000    0.00000    1.020054    0.00000
# 8    43.02550   45.74385  93.05545  140.35085  100.985364  136.67696
# 9   246.88442  179.78397 412.10269  451.28197  398.841187  639.37019
# 10         NA         NA        NA         NA          NA         NA
# 11         NA         NA        NA         NA          NA         NA
# 12         NA         NA        NA         NA          NA         NA
# 13         NA         NA        NA         NA          NA         NA
# 14   85.02658   95.74294   0.00000  444.80424  148.927911  465.62829
# 15  914.80409  914.87702 543.93123 1473.68394 1064.936570 2104.97964
# 16   67.61150   68.08387  49.85113  142.51009  221.351758  236.28898
# 17  257.12859  188.29446   0.00000    0.00000    0.000000    0.00000
# 18  589.03959  355.31270   0.00000    0.00000    0.000000    0.00000
# 19 1318.42426 1148.91533   0.00000    0.00000    2.040108    0.00000
# 20  268.39717  324.46220 116.31931   90.68824  172.389157  147.48757
# 21 1207.78726 1171.25535   0.00000    0.00000    0.000000    0.00000
# 22  800.06942  913.81321   0.00000    0.00000    0.000000    0.00000
# 23  495.81767  320.20696 440.90556  778.40741  693.636847  730.48817
# 24    9.21975   31.91431  26.58727   34.54790   28.561517   48.64773
# 25  158.78458  104.25343  18.83265   18.35357   54.062872   40.92587
# 26  160.83342  209.57067 210.48255  129.55463   82.624389   82.62393
#    PBS-4        deg
# 1            NA    NA
# 2            NA    NA
# 3   416.8572826  TRUE
# 4     0.0000000 FALSE
# 5     0.0000000 FALSE
# 6    34.1391740  TRUE
# 7     0.0000000  TRUE
# 8   104.2143206 FALSE
# 9   452.7932552 FALSE
# 10           NA    NA
# 11           NA    NA
# 12           NA    NA
# 13           NA    NA
# 14  284.7925831 FALSE
# 15 1467.0860829  TRUE
# 16  189.5622557  TRUE
# 17    0.0000000 FALSE
# 18    0.0000000  TRUE
# 19    0.8983993  TRUE
# 20  130.2679008 FALSE
# 21    0.0000000  TRUE
# 22    0.0000000  TRUE
# 23  628.8795211  TRUE
# 24   35.0375733 FALSE
# 25   26.9519795 FALSE
# 26   98.8239247  TRUE

# %%
joint_data %>%
    select(c(gene, log2.FC., P.adj, log2FoldChange, padj, deg))
# Out:
#    gene          log2.FC.   P.adj        log2FoldChange padj         deg
# 1  4930518I15Rik  0.5813053 5.196073e-03         NA               NA    NA
# 2  4933417C20Rik  0.5930864 2.684696e-03         NA               NA    NA
# 3  C4b           -0.9462081 1.110000e-08 -2.1075094     7.054642e-07  TRUE
# 4  Camp           1.5316696 9.590000e-28 10.4278723     5.449817e-02 FALSE
# 5  Cd177          0.6177664 7.040000e-06  8.2816908     1.431517e-01 FALSE
# 6  Cers4          0.7468119 6.390000e-05  1.6496472     9.171215e-03  TRUE
# 7  Chil3          1.2554221 1.500000e-19  9.7334149     1.582286e-02  TRUE
# 8  Farp1         -0.8042760 5.820000e-06 -1.0688362     1.613724e-01 FALSE
# 9  Foxn2         -0.6160310 1.008326e-03 -0.8902990     8.482709e-02 FALSE
# 10 Gm26917       -0.5937446 1.687751e-03         NA               NA    NA
# 11 Gm37298        0.6153384 3.059895e-03         NA               NA    NA
# 12 Gm37352        0.5962007 3.083542e-03         NA               NA    NA
# 13 Gm43984        0.5822144 5.591232e-03         NA               NA    NA
# 14 Hspa1b        -0.6731192 1.256920e-04 -2.7092209     4.163274e-01 FALSE
# 15 Hsph1         -0.5924695 3.071154e-03 -1.0536145     2.432693e-03  TRUE
# 16 Itpr3         -0.6782613 4.695910e-04 -1.4114863     4.738703e-03  TRUE
# 17 Lcn2           0.9518617 3.830000e-12  9.5174921     8.226805e-02 FALSE
# 18 Ltf            2.1332139 2.550000e-51 10.7709230     4.617099e-02  TRUE
# 19 Ngp            2.1515506 3.010000e-52  9.9691827     3.186159e-03  TRUE
# 20 Rabl3          0.6617301 4.272260e-04  0.8992766     2.576199e-01 FALSE
# 21 S100a8         2.5643896 1.260000e-73 12.0335434     2.679847e-02  TRUE
# 22 S100a9         0.7762565 1.110000e-08 11.5005318     3.647687e-02  TRUE
# 23 Ttc37         -0.6149097 9.850000e-05 -0.7637835     2.432693e-03  TRUE
# 24 Uprt          -0.5989007 3.726673e-03 -0.8796043     7.019492e-01 FALSE
# 25 Vsig10         0.7594069 2.670000e-05  1.6127602     2.444439e-01 FALSE
# 26 Zfp414         0.6269820 1.597628e-03  0.9643545     3.697553e-02  TRUE

# %%
joint_data %>%
    select(-c(log2.FC., P.adj, log2FoldChange, padj))
# Out:
#    gene          PBS_1       PBS_2        PBS_3       PBS_4        CML_1
# 1  4930518I15Rik    41.40551    66.635105    71.80520 6.866336e+01  138.75066
# 2  4933417C20Rik    17.43390    19.477954    14.82934 1.373267e+01   46.93037
# 3  C4b             327.97521   345.477393   736.78381 4.211353e+02   90.80007
# 4  Camp              0.00000     0.000000     0.00000 0.000000e+00  142.83157
# 5  Cd177             0.00000     0.000000     0.00000 0.000000e+00   33.66744
# 6  Cers4            39.22627    46.131996    28.87818 4.119802e+01   90.80007
# 7  Chil3             0.00000     1.025155     0.00000 0.000000e+00  108.14390
# 8  Farp1           141.65042   101.490391   139.70795 1.052838e+02   46.93037
# 9  Foxn2           452.19174   419.288587   668.10057 4.595868e+02  254.03614
# 10 Gm26917       13130.99430 19428.746440 23192.29959 1.653414e+04 6730.42745
# 11 Gm37298          45.76398    80.987282    85.07355 4.852211e+01  143.85179
# 12 Gm37352          66.46674    57.408706    54.63439 6.591683e+01  113.24503
# 13 Gm43984          54.48093    63.559639   120.97615 6.225478e+01  141.81134
# 5    0.00000    0.00000    0.000000    0.00000    0.0000000 FALSE
# 6   85.30082   19.43319   46.922493   28.57089   34.1391740  TRUE
# 7    0.00000    0.00000    1.020054    0.00000    0.0000000  TRUE
# 8   93.05545  140.35085  100.985364  136.67696  104.2143206 FALSE
# 9  412.10269  451.28197  398.841187  639.37019  452.7932552 FALSE
# 10        NA         NA          NA         NA           NA    NA
# 11        NA         NA          NA         NA           NA    NA
# 12        NA         NA          NA         NA           NA    NA
# 13        NA         NA          NA         NA           NA    NA
# 14   0.00000  444.80424  148.927911  465.62829  284.7925831 FALSE
# 15 543.93123 1473.68394 1064.936570 2104.97964 1467.0860829  TRUE
# 16  49.85113  142.51009  221.351758  236.28898  189.5622557  TRUE
# 17   0.00000    0.00000    0.000000    0.00000    0.0000000 FALSE
# 18   0.00000    0.00000    0.000000    0.00000    0.0000000  TRUE
# 19   0.00000    0.00000    2.040108    0.00000    0.8983993  TRUE
# 20 116.31931   90.68824  172.389157  147.48757  130.2679008 FALSE
# 21   0.00000    0.00000    0.000000    0.00000    0.0000000  TRUE
# 22   0.00000    0.00000    0.000000    0.00000    0.0000000  TRUE
# 23 440.90556  778.40741  693.636847  730.48817  628.8795211  TRUE
# 24  26.58727   34.54790   28.561517   48.64773   35.0375733 FALSE
# 25  18.83265   18.35357   54.062872   40.92587   26.9519795 FALSE
# 26 210.48255  129.55463   82.624389   82.62393   98.8239247  TRUE

# %% [markdown]
# # Z-scores

# %%
plot_z_score_heatmap = function(de_genes, fp){
    de_genes = de_genes[de_genes %in% rownames(z_scores)]
    data = z_scores[de_genes,]
    hc = hclust(dist(data[,order]), method = "complete")
    xx = pheatmap(data[hc$order, order],
            cluster_rows=F,
            cluster_cols=F,
            show_rownames=T,
            show_colnames=F,
            annotation_col=annot,
            annotation_row=NULL,
            annotation_colors = annot_colors,
            color=rev(brewer.pal(11, "RdBu")),
            breaks = seq(-3.5, 3.5, length=12),
            main = "DE genes in CML vs PBS")
    pdf(fp)
    grid::grid.newpage()
    grid::grid.draw(xx$gtable)
    dev.off()
}

# %% [markdown]
# ## in CML / PBS samples

# %%
z_scores = t(scale(t(norm_counts %>% select(-gene))))
rownames(z_scores) = norm_counts$gene
head(z_scores)
# Out:
#               CML-1       CML-2      CML-3      CML-4      PBS-1
# 0610005C13Rik -0.05393378 -0.4252086 -0.7598723 -0.3366759 -0.74868080
# 0610009B22Rik  2.07198126 -1.5384334  0.1171830 -0.1601688  0.07015591
# 0610009L18Rik  0.36706103 -0.1242125  1.1207439  1.1082310 -0.37311316
# 0610010F05Rik -1.68709280  0.7881944 -0.4140327  0.1571092  0.97300756
# 0610010K14Rik  0.32208787  0.2689597 -0.6983301  0.8977286  0.56965316
# 0610012G03Rik -2.00502610 -0.5505675  0.7023673  1.2388698 -0.40144545
#               PBS-2      PBS-3       PBS-4
# 0610005C13Rik -0.7908436  1.76652540  1.3486896
# 0610009B22Rik  0.1670043 -0.32431142 -0.4034110
# 0610009L18Rik  0.5450361 -1.78803811 -0.8557082
# 0610010F05Rik -0.9204291  1.23494251 -0.1316990
# 0610010K14Rik  1.0264241 -2.00089417 -0.3856292
# 0610012G03Rik  0.2995700  0.09237846  0.6238533

# %%
annot = metadata %>% select(treatment) %>% as.data.frame
rownames(annot) = metadata$sample
annot_colors = list()
annot_colors$treatment = c("#65ce41","#c3a7f9")
names(annot_colors$treatment) = c("CML", "PBS")
order = metadata$sample

# %% [markdown]
# DEGs for CML vs PBS (abs(FC) > 1.5)

# %%
deg1$gene
# Out:
#  [1] "2810013P06Rik" "4833419F23Rik" "A430033K04Rik" "AI854703"
#  [5] "Atad2"         "C4b"           "Ccl22"         "Cenpe"
#  [9] "Cers4"         "Chic1"         "Chil3"         "F630028O10Rik"
# [13] "Fos"           "Gbp6"          "Glb1l"         "Gm5420"
# [17] "Hsph1"         "Igf2bp2"       "Ipo4"          "Itpr3"
# [21] "Kcna7"         "Ltf"           "Maob"          "N4bp3"
# [25] "Nek5"          "Ngp"           "Pglyrp1"       "Rora"
# [29] "S100a8"        "S100a9"        "Scai"          "Sema3c"
# [33] "Setx"          "Sh2d5"         "She"           "Snap91"
# [37] "Snhg17"        "Tle6"          "Ttc37"         "Vat1l"
# [41] "Wdr5b"         "Zfp414"        "Zkscan2"

# %%
plot_z_score_heatmap(deg1$gene, paste(dir_path, 'z-score-cml-pbs-deg-high-fc.pdf', sep=''))
# Out:
# png
#   2
# plot without title

# %% [markdown]
# DEGs for CML vs PBS (abs(FC) > 0.58)

# %%
deg2$gene
# Out:
#  [1] "2810013P06Rik" "4833419F23Rik" "A430033K04Rik" "AI854703"
#  [5] "Alkbh4"        "Atad2"         "Atp7a"         "C4b"
#  [9] "Ccl22"         "Cenpe"         "Cers4"         "Chic1"
# [13] "Chil3"         "Clk1"          "Dcun1d4"       "F630028O10Rik"
# [17] "Fos"           "Gbp6"          "Glb1l"         "Gm5420"
# [21] "Hsph1"         "Igf2bp2"       "Ipo4"          "Itpr3"
# [25] "Kcna7"         "Ltf"           "Maob"          "N4bp3"
# [29] "Nek5"          "Ngp"           "Npnt"          "Pacs2"
# [33] "Pglyrp1"       "Rora"          "S100a8"        "S100a9"
# [37] "Scai"          "Sema3c"        "Setx"          "Sh2d5"
# [41] "She"           "Slc39a8"       "Snap91"        "Snhg17"
# [45] "Tbc1d23"       "Tle6"          "Ttc37"         "Unk"
# [49] "Usp7"          "Vat1l"         "Wdr5b"         "Xpo1"
# [53] "Xpo7"          "Zfp414"        "Zkscan2"

# %%
plot_z_score_heatmap(deg2$gene, paste(dir_path, 'z-score-cml-pbs-deg-low-fc.pdf', sep=''))
# Out:
# png
#   2
# plot without title

# %% [markdown]
# ##  in non CML / PBS samples

# %%
load(paste(dp, "filtered_z_scores.RData", sep=''))
load(paste(dp, "col_order.RData", sep=''))
load(paste(dp, "annot_col.RData", sep=''))
load(paste(dp, "annot_colors.RData", sep=''))

# %%
annot = annot_col$ma %>%
    rownames_to_column('sample') %>%
    filter(Age == 'Old' ) %>%
    select(-Age)
order = col_order$ma[col_order$ma %in% annot$sample]
samples = annot$sample
annot = annot %>% select(-sample) %>% as.data.frame
rownames(annot) = samples

# %%
deg1$gene
# Out:
#  [1] "2810013P06Rik" "4833419F23Rik" "A430033K04Rik" "AI854703"
#  [5] "Atad2"         "C4b"           "Ccl22"         "Cenpe"
#  [9] "Cers4"         "Chic1"         "Chil3"         "F630028O10Rik"
# [13] "Fos"           "Gbp6"          "Glb1l"         "Gm5420"
# [17] "Hsph1"         "Igf2bp2"       "Ipo4"          "Itpr3"
# [21] "Kcna7"         "Ltf"           "Maob"          "N4bp3"
# [25] "Nek5"          "Ngp"           "Pglyrp1"       "Rora"
# [29] "S100a8"        "S100a9"        "Scai"          "Sema3c"
# [33] "Setx"          "Sh2d5"         "She"           "Snap91"
# [37] "Snhg17"        "Tle6"          "Ttc37"         "Vat1l"
# [41] "Wdr5b"         "Zfp414"        "Zkscan2"

# %% [markdown]
# DEGs for CML vs PBS (abs(FC) > 1.5)

# %%
plot_z_score_heatmap(deg1$gene, paste(dir_path, 'z-score-deg-high-fc.pdf', sep=''))
# Out:
# png
#   2
# plot without title

# %% [markdown]
# DEGs for CML vs PBS (abs(FC) > 0.58)

# %%
plot_z_score_heatmap(deg2$gene, paste(dir_path, 'z-score-deg-low-fc.pdf', sep=''))
# Out:
# png
#   2
# plot without title

# %% [markdown]
# DEGs for CML vs PBS from Omar's analysis

# %%
plot_z_score_heatmap(cml_pbs_deg$Gene, paste(dir_path, 'z-score-deg-omar.pdf', sep=''))
# Out:
# png
#   2
# plot without title

# %% [markdown]
# # Volcano plots for SPF vs GF highlighting DEG in CML vs PBS

# %%
load(paste(dp, "4-analyze_microbiota_effect_given_ages/deg_results.RData", sep=''))

# %%
head(deg_results[['GF vs SPF (Old)']])
# Out:
#   genes         baseMean    log2FoldChange lfcSE     stat        pvalue
# 1 0610005C13Rik    4.140634 -1.595129524   0.9878642 -1.61472558 0.106370136
# 2 Erg28          732.036659  0.007466096   0.1559357  0.04787932 0.961812424
# 3 0610009B22Rik 1082.446306 -0.158127780   0.1633142 -0.96824268 0.332923183
# 4 0610009L18Rik   36.146091 -0.217717521   0.3354830 -0.64896747 0.516359405
# 5 Dele1          288.059233  0.535077026   0.1752914  3.05250053 0.002269433
# 6 0610010F05Rik  419.404222 -0.081027068   0.2807825 -0.28857588 0.772905953
#   padj       sign_padj sign_padj_and_fc
# 1 0.26064849 FALSE     FALSE
# 2 0.98210249 FALSE     FALSE
# 3 0.54548918 FALSE     FALSE
# 4 0.70989288 FALSE     FALSE
# 5 0.01916616  TRUE     FALSE
# 6 0.88390733 FALSE     FALSE

# %%
sign_fc = 1.5
sign_adj_pvalue = 0.05

# %%
colors = setNames(c("cornflowerblue","grey","firebrick"),c('Down', 'Non significant', 'Up'))

get_cmp_data = function(comp, deg_results, cml_pbs_deg) {
    deg_res = deg_results[[comp]] %>%
        filter(!is.na(sign_padj_and_fc)) %>%
        mutate(log2FoldChange=-log2FoldChange) %>%
        mutate(Expression=ifelse(
            sign_padj_and_fc & log2FoldChange >= log2(sign_fc),
            'Up',
            ifelse(
                sign_padj_and_fc & log2FoldChange <= -log2(sign_fc),
                'Down',
                'Non significant'))) %>%
        mutate(labels=ifelse(genes %in% cml_pbs_deg & Expression != 'Non significant', genes, "")) %>%
        select(genes, log2FoldChange, pvalue, Expression, labels)
    return(deg_res)
}

plot_volcanoplots = function(deg_res, fp) {
    my_plot = ggplot(data=deg_res, aes(log2FoldChange,-log10(pvalue))) +
        geom_point(aes(col=Expression), size=3) +
        scale_colour_manual(values=colors) +
        scale_fill_manual(values=colours) +
        theme(panel.grid.major=element_blank(),
            panel.grid.minor= element_blank(),
            panel.background=element_blank(),
            axis.line=element_line(colour = "black"),
            legend.key=element_blank(),
            text = element_text(size = 15)) +
        xlab("log2(Fold Change)") +
        ylab("-log10(P-Value)") +
        geom_text_repel(aes(label=labels, col=Expression),
            min.segment.length=0,
            box.padding=4,
            point.padding=0.4,
            max.overlaps=Inf,
            show.legend=FALSE,
            size=4.5) +
        xlim(xlim[1], xlim[2]) +
        ylim(ylim[1], ylim[2])
    ggsave(fp, plot=my_plot)
    plot(my_plot)
}

# %% [markdown]
# ## Highlighting DEGs for CML vs PBS (abs(FC) > 1.5)

# %%
xlim = c(-10,35)
ylim = c(0,175)

# %% [markdown]
# SPF vs GF (Old)

# %%
comp = 'GF vs SPF (Old)'
deg_res = get_cmp_data(comp, deg_results, deg1$gene)
plot_volcanoplots(deg_res, paste(dir_path, 'volcanoplot-spf-gf-old-high-fc.pdf', sep=''))
# Out:
# Saving 6.67 x 6.67 in image
#
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# Warning message:
# “Removed 15 rows containing missing values (geom_text_repel).”
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# Warning message:
# “Removed 15 rows containing missing values (geom_text_repel).”
# plot without title

# %% [markdown]
# ## Highlighting DEGs for CML vs PBS (abs(FC) > 0.58)

# %%
xlim = c(-10,35)
ylim = c(0,175)

# %% [markdown]
# SPF vs GF (Old)

# %%
comp = 'GF vs SPF (Old)'
deg_res = get_cmp_data(comp, deg_results, deg2$gene)
plot_volcanoplots(deg_res, paste(dir_path, 'volcanoplot-spf-gf-old-low-fc.pdf', sep=''))
# Out:
# Saving 6.67 x 6.67 in image
#
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# Warning message:
# “Removed 15 rows containing missing values (geom_text_repel).”
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# Warning message:
# “Removed 15 rows containing missing values (geom_text_repel).”
# plot without title

# %% [markdown]
# ## Highlighting DEGs for CML vs PBS from Omar's analysis

# %%
xlim = c(-10,50)
ylim = c(0,300)

# %% [markdown]
# GF vs SPF (Male, Old)

# %%
comp = 'GF vs SPF (Old)'
deg_res = get_cmp_data(comp, deg_results, cml_pbs_deg$Gene)
plot_volcanoplots(deg_res, paste(dir_path, 'volcanoplot-spf-gf-old-omar.pdf', sep=''))
# Out:
# Saving 6.67 x 6.67 in image
#
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# Warning message:
# “Removed 15 rows containing missing values (geom_text_repel).”
# Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# Warning message:
# “Removed 15 rows containing missing values (geom_text_repel).”
# plot without title

# %% [markdown]
# # Citations

# %%
citation("rentrez")

# %%
citation("DESeq2")
