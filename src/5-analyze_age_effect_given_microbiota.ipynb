# %% [markdown]
# Comparison between the ages (Young, Old) for the microbiota
#
# **Need to run first:**
# - [`../0-prepare_data`](../0-prepare_data.ipynb)
# - [`1-extract_samples`](1-extract_samples.ipynb)
# - [`2-run_dge_analysis`](2-run_dge_analysis.ipynb)
# - [`3-previsualize_data`](3-previsualize_data.ipynb)
#
# **Table of content**
# 1. [Differentially expressed genes](#Differentially-expressed-genes)
# 2. [Stats about the DEG](#Stats-about-the-DEG)
# 3. [DEG with significant p-value and fold change](#DEG-with-significant-p-value-and-fold-change)
#     1. [Log2FC](#Log2FC)
#     2. [Z-score](#Z-score)
# 4. [Co-expression (WGCNA)](#Co-expression-(WGCNA))
#     1. [Z-score in modules](#Z-score-in-modules)
#     2. [Genes in modules](#Genes-in-modules)
# 5. [Enrichment analysis](#Enrichment-analysis)
#     1. [GO analysis](#GO-analysis)
#     2. [KEGG pathways](#KEGG-pathways)
#
# *Generated from a Jupyter Notebook - [Sources](https://github.com/bebatut/neuromac_GF_mices/blob/master/src/microbiota-driven/5-analyze_age_effect_given_microbiota.ipynb)*

# %% [markdown]
# # Loads
#
# ## Libraries and functions

# %%
source("../load_libraries.R")
# Out:
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.3”
# Warning message:
# “package ‘XML’ was built under R version 3.6.3”
# Allowing multi-threading with up to 4 threads.
# Warning message:
# “package ‘reshape’ was built under R version 3.6.3”
# Warning message:
# “package ‘plotly’ was built under R version 3.6.3”
# Warning message:
# “package ‘dplyr’ was built under R version 3.6.3”
# Warning message:
# “package ‘tibble’ was built under R version 3.6.3”
# Warning message:
# “package ‘factoextra’ was built under R version 3.6.3”
# Warning message:
# “package ‘ggrepel’ was built under R version 3.6.3”
# preparing gene to GO mapping data...
#
# preparing IC data...
#
# preparing gene to GO mapping data...
#
# preparing IC data...
#
# preparing gene to GO mapping data...
#
# preparing IC data...

# %%
source("../functions.R")

# %% [markdown]
# ## Data

# %%
dp = "../../results/dge/microbiota-driven/"
dir_path = paste(dp, "5-analyze_age_effect_given_microbiota/", sep='')
dir.create(dir_path, showWarnings = FALSE)

# %%
load("../../results/dge/gene_length.RData")
load(paste(dp, "filtered_metadata.RData", sep=''))
load(paste(dp, "dge.RData", sep=''))
load(paste(dp, "contrasts.RData", sep=''))
load(paste(dp, "filtered_norm_counts.RData", sep=''))
load(paste(dp, "filtered_z_scores.RData", sep=''))
load(paste(dp, "dge_net_pal2.RData", sep=''))
load(paste(dp, "col_order.RData", sep=''))
load(paste(dp, "annot_col.RData", sep=''))
load(paste(dp, "annot_colors.RData", sep=''))
load(paste(dp, "genes_in_modules.RData", sep=''))
load(paste(dp, "all_deg_genes.RData", sep=''))

# %% [markdown]
# # Differentially expressed genes

# %% [markdown]
# Extract DEG between Young and Old for the different microbiota
# - Threshold for adjusted p-value: 0.05
# - Threshold for adjusted significant fold change: 1.5
#
# Table with the factors / constrasts

# %%
sub_contrasts = contrasts %>%
    filter(Info == 'Old vs Young (SPF)' | 
           Info == 'Old vs Young (GF)')
sub_contrasts
# Out:
#   Info               Intercept GF vs SPF Old vs Young GF & Old
# 1 Old vs Young (SPF) 0         0         1            0
# 2 Old vs Young (GF)  0         0         1            1

# %%
deg_results = lapply(sub_contrasts$Info, function(x) get_dge_results(x, dge, sub_contrasts))
names(deg_results) = sub_contrasts$Info

# %% [markdown]
# Extract the log2FC of the DEG

# %%
deg = extract_DEG_log2FC(deg_results, dir_path)
# Out:
# Warning message:
# “`data_frame()` is deprecated as of tibble 1.1.0.
# Please use `tibble()` instead.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”

# %%
all_deg_genes = unique(c(all_deg_genes, deg$sign_fc_deg$genes))
save(all_deg_genes, file=paste(dir_path, "all_deg_genes.RData", sep=''))

# %% [markdown]
# # Stats

# %%
deg = extract_DEG_stats(deg, dir_path)
deg$stat
# Out:
# Warning message:
# “`funs()` is deprecated as of dplyr 0.8.0.
# Please use a list of either functions or lambdas:
#
#   # Simple named list:
#   list(mean = mean, median = median)
#
#   # Auto named with `tibble::lst()`:
#   tibble::lst(mean, median)
#
#   # Using lambdas
#   list(~ mean(., trim = .2), ~ median(., na.rm = TRUE))
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_warnings()` to see where this warning was generated.”
# Using type as id variables
# plot without title
#                                                       Old vs Young (SPF)
# All DEG (Wald padj < 0.05)                            2093
# All over-expressed genes (Wald padj < 0.05 & FC > 0)  1287
# All under-expressed genes (Wald padj < 0.05 & FC < 0)  806
# DEG (Wald padj < 0.05 & abs(FC) >= 1.5)               1415
# Over-expressed genes (Wald padj < 0.05 & FC >= 1.5)    820
# Under-expressed genes (Wald padj < 0.05 & FC <= -1.5)  595
#                                                       Old vs Young (GF)
# All DEG (Wald padj < 0.05)                            2193
# All over-expressed genes (Wald padj < 0.05 & FC > 0)  1107
# All under-expressed genes (Wald padj < 0.05 & FC < 0) 1086
# DEG (Wald padj < 0.05 & abs(FC) >= 1.5)               1545
# Over-expressed genes (Wald padj < 0.05 & FC >= 1.5)    566
# Under-expressed genes (Wald padj < 0.05 & FC <= -1.5)  979
# Plot with title “”

# %% [markdown]
# All DEG (Wald padj < 0.05)

# %%
plot_sign_DEG_upset(deg)
# Out:
# plot without title

# %% [markdown]
# DEG (Wald padj < 0.05 & abs(FC) > 1.5)

# %%
pdf(paste(dir_path, "sign_FC_DEG_upset.pdf", sep=''))
plot_sign_FC_DEG_upset(deg)
dev.off()
plot_sign_FC_DEG_upset(deg)
# Out:
# pdf
#   2
# plot without title

# %% [markdown]
# # DEG (Wald padj < 0.05 & abs(FC) > 1.5)

# %% [markdown]
# ## Log2FC

# %%
data = deg$sign_fc_deg %>% select(-genes)
fc_annot = data.frame(Comparison = rep("Old VS Young",2),
                      Microbiota = c("SPF","GF"),
                      row.names = colnames(data))
plot_fc_heatmap(data, fc_annot)
# Out:
# plot without title

# %% [markdown]
# ## Z-score

# %%
comps = list(
    "Old vs Young (SPF)" = c(metadata %>% filter(Age == "Young" & Microbiota == "SPF") %>% pull(sample),
                  metadata %>% filter(Age == "Old" & Microbiota == "SPF") %>% pull(sample)),
    "Old vs Young (GF)" = c(metadata %>% filter(Age == "Young" & Microbiota == "GF") %>% pull(sample),
                  metadata %>% filter(Age == "Old" & Microbiota == "GF") %>% pull(sample))
)
comps
# Out:
# $`Old vs Young (SPF)`
#  [1] "SPF_8w_M_2_2"    "SPF_8w_M_3_2"    "SPF_8w_M_4_2"    "SPF_104w_M_1_2"
#  [5] "SPF_104w_M_10_2" "SPF_104w_M_11_2" "SPF_104w_M_12_2" "SPF_104w_M_13_2"
#  [9] "SPF_104w_M_14_2" "SPF_104w_M_2_2"  "SPF_104w_M_4_2"  "SPF_104w_M_5_2"
# [13] "SPF_104w_M_6_2"  "SPF_104w_M_7_2"  "SPF_104w_M_8_2"  "SPF_104w_M_9_2"
#
# $`Old vs Young (GF)`
# [1] "GF_8w_M_1_2"   "GF_8w_M_3_2"   "GF_8w_M_4_2"   "GF_104w_M_1_2"
# [5] "GF_104w_M_2_2" "GF_104w_M_3_2" "GF_104w_M_4_2" "GF_104w_M_5_2"

# %% [markdown]
# ### Column order: age  -  microbiota

# %%
plot_z_score_heatmap(z_scores,
                     deg$sign_fc_deg$genes,
                     col_order$am,
                     annot_col$am,
                     "All DE genes in age comparison for any microbiota",
                     col_order$am)
pdf(paste(dir_path, "z_score_am.pdf", sep=''))
plot_z_score_heatmap(z_scores,
                     deg$sign_fc_deg$genes,
                     col_order$am,
                     annot_col$am,
                     "All DE genes in age comparison for any microbiota",
                     col_order$am)
dev.off()
# Out:
# pdf
#   3
# plot without title

# %%
for(comp in names(comps)){
    plot_z_score_heatmap(z_scores,
        deg$sign_fc_deg %>% filter(!is.na((!!as.name(comp)))) %>% pull(genes),
        col_order$am,
        annot_col$am,
        paste("DE genes in", comp),
        comps[[comp]])
}
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### Column order: microbiota - age

# %%
plot_z_score_heatmap(z_scores,
                     deg$sign_fc_deg$genes,
                     col_order$ma,
                     annot_col$ma,
                     "All DE genes in age comparison for any microbiota",
                     col_order$ma)
pdf(paste(dir_path, "z_score_ma.pdf", sep=''))
plot_z_score_heatmap(z_scores,
                     deg$sign_fc_deg$genes,
                     col_order$ma,
                     annot_col$ma,
                     "All DE genes in age comparison for any microbiota",
                     col_order$ma)
dev.off()
# Out:
# pdf
#   3
# plot without title

# %%
for(comp in names(comps)){
    plot_z_score_heatmap(z_scores,
        deg$sign_fc_deg %>% filter(!is.na((!!as.name(comp)))) %>% pull(genes),
        col_order$ma,
        annot_col$ma,
        paste("DE genes in", comp),
        comps[[comp]])
}
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Co-expression (WGCNA)

# %% [markdown]
# ## Z-score in modules

# %%
comps = names(comps)

# %% [markdown]
# ### Column order: age - microbiota

# %%
plot_z_score_heatmap_with_modules(z_scores,
                                  rownames(z_scores),
                                  col_order$am,
                                  annot_col$am,
                                  genes_in_modules,
                                  "All genes")
# Out:
# plot without title

# %%
for(comp in comps){
    plot_z_score_heatmap_with_modules(z_scores,
        deg$sign_fc_deg %>% filter(!is.na((!!as.name(comp)))) %>% pull(genes),
        col_order$am,
        annot_col$am,
        genes_in_modules,
        paste("DE genes in", comp))
}
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### Column order: microbiota - age

# %%
plot_z_score_heatmap_with_modules(z_scores,
    rownames(z_scores),
    col_order$ma,
    annot_col$ma,
    genes_in_modules,
    "All genes")
# Out:
# plot without title

# %%
for(comp in comps){
    plot_z_score_heatmap_with_modules(z_scores,
        deg$sign_fc_deg %>% filter(!is.na((!!as.name(comp)))) %>% pull(genes),
        col_order$ma,
        annot_col$ma,
        genes_in_modules,
        paste("DE genes in", comp))
}
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## Genes in modules

# %%
for(comp in comps){
    plot_top_deg_in_modules(deg$sign_fc_deg, comp, genes_in_modules)
}
options(repr.plot.width=7, repr.plot.height=7)
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Enrichment analysis

# %%
deg = fit_proba_weighting_function(deg, gene_length)
# Out:
# Warning message in pcls(G):
# “initial point very close to some inequality constraints”
# Warning message in pcls(G):
# “initial point very close to some inequality constraints”

# %% [markdown]
# ## GO analysis

# %%
deg = extract_GO_terms(deg, dir_path, "../../data/go_term_to_exclude.csv")
# Out:
# Warning message in stack.default(getgo(l$sign_fc_deg$genes, "mm10", "geneSymbol")):
# “non-vector elements will be ignored”

# %% [markdown]
# ### Biological process

# %% [markdown]
# Dot-plot with the 10 most significant p-values for the different comparison

# %%
plot_top_go(deg, "BP", 10)
# Out:
# Using category as id variables
#
# Using category, type as id variables
# plot without title

# %% [markdown]
# ### Cellular components

# %% [markdown]
# Dot-plot with the 10 most significant p-values for the different comparison

# %%
plot_top_go(deg, "CC", 10)
# Out:
# Using category as id variables
#
# Using category, type as id variables
# plot without title

# %% [markdown]
# ### Molecular functions

# %% [markdown]
# Dot-plot with the 10 most significant p-values for the different comparison

# %%
plot_top_go(deg, "MF", 10)
# Out:
# Using category as id variables
#
# Using category, type as id variables
# plot without title

# %% [markdown]
# ## KEGG pathways

# %%
deg = extract_KEGG_pathways(deg, dir_path)
# Out:
# Warning message in stack.default(getgo(l$sign_fc_deg$genes, "mm10", "geneSymbol", :
# “non-vector elements will be ignored”

# %%
plot_kegg_pathways(deg$KEGG$over$category,
                   deg$sign_fc_deg,
                   paste(dir_path, '/kegg/over_repr_kegg/', sep=''))
# Out:
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu03010.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu03010.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05150.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05150.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05140.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05140.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu04514.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu04514.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05330.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05330.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05323.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05323.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu04940.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu04940.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu04145.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu04145.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu04612.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu04612.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05332.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05332.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu04672.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu04672.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu03030.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu03030.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in cbind(blk.ind, j):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(blk.ind, j):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(blk.ind, j):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(blk.ind, j):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(blk.ind, j):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(blk.ind, j):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu00600.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu00600.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05310.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05310.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05320.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05320.pathview.multi.png' umbenennen. Grund 'No such file or directory'”
# [1] "Note: 73 of 2417 unique input IDs unmapped."
# Warning message in file.rename(from = paste("mmu", cat, ".pathview.multi.png", sep = ""), :
# “kann Datei 'mmu05416.pathview.multi.png' nicht in '../../results/dge/microbiota-driven/5-analyze_age_effect_given_microbiota//kegg/over_repr_kegg/mmu05416.pathview.multi.png' umbenennen. Grund 'No such file or directory'”

# %% [markdown]
# Pathway graphs available in `../results/dge/sex-driven-aging/sex-effect/kegg/over_repr_kegg/` folder

# %%
plot_kegg_pathways(deg$under_represented_KEGG[,"category"],
                   deg$fc_deg,
                   paste(dir_path, '/kegg/under_repr_kegg/', sep=''))

# %% [markdown]
# Pathway graphs available in `../results/dge/sex-driven-aging/sex-effect/kegg/under_repr_kegg/` folder

# %% [markdown]
# # Citations

# %%
citation("pheatmap")
# Out:
# To cite package ‘pheatmap’ in publications use:
#
#   Raivo Kolde (2019). pheatmap: Pretty Heatmaps. R package version
#   1.0.12. https://CRAN.R-project.org/package=pheatmap
#
# A BibTeX entry for LaTeX users is
#
#   @Manual{,
#     title = {pheatmap: Pretty Heatmaps},
#     author = {Raivo Kolde},
#     year = {2019},
#     note = {R package version 1.0.12},
#     url = {https://CRAN.R-project.org/package=pheatmap},
#   }
#
# ATTENTION: This citation information has been auto-generated from the
# package DESCRIPTION file and may need manual editing, see
# ‘help("citation")’.

# %%
citation("pathview")
# Out:
# To cite pathview:
#
#   Luo, W. and Brouwer C., Pathview: an R/Bioconductor package for
#   pathway-based data integration and visualization. Bioinformatics,
#   2013, 29(14): 1830-1831, doi: 10.1093/bioinformatics/btt285
#
# A BibTeX entry for LaTeX users is
#
#   @Article{,
#     author = {{Luo} and {Weijun} and {Brouwer} and {Cory}},
#     title = {Pathview: an R/Bioconductor package for pathway-based data integration and visualization},
#     journal = {Bioinformatics},
#     year = {2013},
#     doi = {10.1093/bioinformatics/btt285},
#     volume = {29},
#     number = {14},
#     pages = {1830-1831},
#   }
#
# This free open-source software implements academic research by the
# authors. Its development took a large amount of extra time and effort.
# If you use it, please support the project by citing the listed journal
# articles.
